# %%
import os
import dotenv

dotenv.load_dotenv()

if not os.getenv("GITHUB_TOKEN"):
    raise ValueError("GITHUB_TOKEN is not set")

os.environ["OPENAI_API_KEY"] = os.getenv("GITHUB_TOKEN")
os.environ["OPENAI_BASE_URL"] = "https://models.inference.ai.azure.com/"

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, StorageContext, load_index_from_storage
from llama_index.core import Settings
import os

llm = OpenAI(
    model="gpt-4o-mini",
    api_key=os.getenv("OPENAI_API_KEY"),
    api_base=os.getenv("OPENAI_BASE_URL"),
)

embed_model = OpenAIEmbedding(
    model="text-embedding-3-small",
    api_key=os.getenv("OPENAI_API_KEY"),
    api_base=os.getenv("OPENAI_BASE_URL"),
)

Settings.embed_model = embed_model

# %%
import phoenix as px
px.launch_app()
# Out:
# 2026-02-03 05:46:29,975 - INFO - 📋 Ensuring phoenix working directory: /home/codespace/.phoenix
# 2026-02-03 05:46:29,976 - WARNING - Existing running Phoenix instance detected! Shutting it down and starting a new instance...
# 2026-02-03 05:46:30,141 - INFO - Context impl SQLiteImpl.
# 2026-02-03 05:46:30,142 - INFO - Will assume transactional DDL.
# 2026-02-03 05:46:30,156 - INFO - Server umap params: UMAPParameters(min_dist=0.0, n_neighbors=30, n_samples=500)
# 🌍 To view the Phoenix app in your browser, visit http://localhost:6006/
# 📖 For more information on how to use Phoenix, check out https://arize.com/docs/phoenix

# %%
from openinference.instrumentation.llama_index import LlamaIndexInstrumentor
from phoenix.otel import register

tracer_provider = register()
LlamaIndexInstrumentor().instrument(tracer_provider=tracer_provider)
# Out:
# 2026-02-03 05:46:30,443 - WARNING - Overriding of current TracerProvider is not allowed
# 2026-02-03 05:46:30,443 - WARNING - Attempting to instrument while already instrumented
# 🔭 OpenTelemetry Tracing Details 🔭
# |  Phoenix Project: default
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: localhost:4317
# |  Transport: gRPC
# |  Transport Headers: {}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  ⚠️ WARNING: It is strongly advised to use a BatchSpanProcessor in production environments.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.

# %%
from llama_index.core import StorageContext, load_index_from_storage
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

try:
    storage_context = StorageContext.from_defaults(
        persist_dir="./local_index"
    )

    index = load_index_from_storage(storage_context)

except:
    documents = SimpleDirectoryReader("data").load_data()
    index = VectorStoreIndex.from_documents(documents, insert_batch_size=150)
    index.storage_context.persist(persist_dir="./local_index")
# Out:
# 2026-02-03 05:46:30,469 - INFO - Loading all indices.

# %%
# solution
query_engine = index.as_query_engine(
  llm=llm
)
query_engine.query("Where does rag is implemented?")
# Out:
# 2026-02-03 05:46:31,844 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/embeddings "HTTP/1.1 200 OK"
# 2026-02-03 05:46:33,866 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/chat/completions "HTTP/1.1 200 OK"
# Response(response='Retrieval-Augmented Generation (RAG) is implemented in scenarios where accurate and up-to-date information is needed, such as in applications that require responses based on external, trusted sources like databases or documents.', source_nodes=[NodeWithScore(node=TextNode(id_='bd700193-a4e5-48a7-9933-9cda1fa7632a', embedding=None, metadata={'file_path': '/workspaces/introduction_to_Retrival_Ugmented_generation/data/data.txt', 'file_name': 'data.txt', 'file_type': 'text/plain', 'file_size': 360, 'creation_date': '2026-02-01', 'last_modified_date': '2026-02-01'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6c50621c-d633-450c-8b90-f5b010b031d6', node_type='4', metadata={'file_path': '/workspaces/introduction_to_Retrival_Ugmented_generation/data/data.txt', 'file_name': 'data.txt', 'file_type': 'text/plain', 'file_size': 360, 'creation_date': '2026-02-01', 'last_modified_date': '2026-02-01'}, hash='db04ec9fdc4175599d8e45c82d60027b7940597a2d9b44833578f068a6dc363e')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Retrieval-Augmented Generation (RAG) is an AI framework that improves Large Language Model (LLM) accuracy by fetching relevant, \nup-to-date data from external, trusted sources (like databases or documents) before generating a response. \nIt reduces hallucinations and provides citations for answers, making it a cost-effective alternative to retraining models.', mimetype='text/plain', start_char_idx=0, end_char_idx=359, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.47307739367459634)], metadata={'bd700193-a4e5-48a7-9933-9cda1fa7632a': {'file_path': '/workspaces/introduction_to_Retrival_Ugmented_generation/data/data.txt', 'file_name': 'data.txt', 'file_type': 'text/plain', 'file_size': 360, 'creation_date': '2026-02-01', 'last_modified_date': '2026-02-01'}})

# %%
query_engine.query("Why rag?")
# Out:
# 2026-02-03 05:46:34,752 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/embeddings "HTTP/1.1 200 OK"
# 2026-02-03 05:46:36,655 - INFO - HTTP Request: POST https://models.inference.ai.azure.com/chat/completions "HTTP/1.1 200 OK"
# Response(response='RAG enhances the accuracy of Large Language Models by retrieving relevant and current information from reliable external sources before generating responses. This approach minimizes inaccuracies, often referred to as hallucinations, and ensures that answers are supported by citations, making it a more efficient option compared to retraining models.', source_nodes=[NodeWithScore(node=TextNode(id_='bd700193-a4e5-48a7-9933-9cda1fa7632a', embedding=None, metadata={'file_path': '/workspaces/introduction_to_Retrival_Ugmented_generation/data/data.txt', 'file_name': 'data.txt', 'file_type': 'text/plain', 'file_size': 360, 'creation_date': '2026-02-01', 'last_modified_date': '2026-02-01'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6c50621c-d633-450c-8b90-f5b010b031d6', node_type='4', metadata={'file_path': '/workspaces/introduction_to_Retrival_Ugmented_generation/data/data.txt', 'file_name': 'data.txt', 'file_type': 'text/plain', 'file_size': 360, 'creation_date': '2026-02-01', 'last_modified_date': '2026-02-01'}, hash='db04ec9fdc4175599d8e45c82d60027b7940597a2d9b44833578f068a6dc363e')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Retrieval-Augmented Generation (RAG) is an AI framework that improves Large Language Model (LLM) accuracy by fetching relevant, \nup-to-date data from external, trusted sources (like databases or documents) before generating a response. \nIt reduces hallucinations and provides citations for answers, making it a cost-effective alternative to retraining models.', mimetype='text/plain', start_char_idx=0, end_char_idx=359, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.40838843995354057)], metadata={'bd700193-a4e5-48a7-9933-9cda1fa7632a': {'file_path': '/workspaces/introduction_to_Retrival_Ugmented_generation/data/data.txt', 'file_name': 'data.txt', 'file_type': 'text/plain', 'file_size': 360, 'creation_date': '2026-02-01', 'last_modified_date': '2026-02-01'}})
